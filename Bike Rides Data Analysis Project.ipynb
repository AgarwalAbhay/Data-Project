# %%
# Importing the required libraries

import pandas as pd
import numpy as np

# %%
# read the csv file
df = pd.read_csv("C:/Users/Abhay/Desktop/Online Courses/Tableau/London Bike Sharing Analysis/london_merged.csv")
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
# Data Understanding
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
# unique values in the weather_code coloumn
df['weather_code'].value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
# unique values in the season coloumn
df['season'].value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
# Creating the dictionary to sepcify the coloumn names to be used - 
new_col_names_dict = {'timestamp':'time', 
                         'cnt':'count', 
                         't1':'real_temp', 
                         't2':'temp_feel_like', 
                         'hum':'humidity_percent', 
                         'wind_speed':'wind_speed_kmph',
                         'weather_code': 'weather',
                         'is_holiday': 'is_holiday',
                         'is_weekend': 'is_weekend',
                         'season': 'season'
                     }

# %%
# Renaming the columns to the required names
df.rename(columns = new_col_names_dict, inplace = True)
df
# Out:
#                       time  count  real_temp  temp_feel_like  \
# 0      2015-01-04 00:00:00    182        3.0             2.0
# 1      2015-01-04 01:00:00    138        3.0             2.5
# 2      2015-01-04 02:00:00    134        2.5             2.5
# 3      2015-01-04 03:00:00     72        2.0             2.0
# 4      2015-01-04 04:00:00     47        2.0             0.0
# ...                    ...    ...        ...             ...
# 17409  2017-01-03 19:00:00   1042        5.0             1.0
# 17410  2017-01-03 20:00:00    541        5.0             1.0
# 17411  2017-01-03 21:00:00    337        5.5             1.5
# 17412  2017-01-03 22:00:00    224        5.5             1.5
# 17413  2017-01-03 23:00:00    139        5.0             1.0
#
#        humidity_percent  wind_speed_kmph  weather  is_holiday  is_weekend  \
# 0                  93.0              6.0      3.0         0.0         1.0
# 1                  93.0              5.0      1.0         0.0         1.0
# ...

# %%
# Chaning the humidity values to percentage
df['humidity_percent'] = df['humidity_percent']/100
df
# Out:
#                       time  count  real_temp  temp_feel_like  \
# 0      2015-01-04 00:00:00    182        3.0             2.0
# 1      2015-01-04 01:00:00    138        3.0             2.5
# 2      2015-01-04 02:00:00    134        2.5             2.5
# 3      2015-01-04 03:00:00     72        2.0             2.0
# 4      2015-01-04 04:00:00     47        2.0             0.0
# ...                    ...    ...        ...             ...
# 17409  2017-01-03 19:00:00   1042        5.0             1.0
# 17410  2017-01-03 20:00:00    541        5.0             1.0
# 17411  2017-01-03 21:00:00    337        5.5             1.5
# 17412  2017-01-03 22:00:00    224        5.5             1.5
# 17413  2017-01-03 23:00:00    139        5.0             1.0
#
#        humidity_percent  wind_speed_kmph  weather  is_holiday  is_weekend  \
# 0                 0.930              6.0      3.0         0.0         1.0
# 1                 0.930              5.0      1.0         0.0         1.0
# ...

# %%
# Creating a weather dictionary to map the written codes to actual values
weather_dict = {'1.0' : 'Clear',
                '2.0' : 'Scattered Clouds',
                '3.0' : 'Broken Clouds',
                '4.0' : 'Cloudy',
                '7.0' : 'Rain',
                '10.0' : 'Rain with Thunderstorm',
                '26.0' : 'Snowfall'}

# Replacing the existing values with the required weather details
df['weather'] = df['weather'].astype('str')
df['weather'] = df['weather'].map(weather_dict)
df
# Out:
#                       time  count  real_temp  temp_feel_like  \
# 0      2015-01-04 00:00:00    182        3.0             2.0
# 1      2015-01-04 01:00:00    138        3.0             2.5
# 2      2015-01-04 02:00:00    134        2.5             2.5
# 3      2015-01-04 03:00:00     72        2.0             2.0
# 4      2015-01-04 04:00:00     47        2.0             0.0
# ...                    ...    ...        ...             ...
# 17409  2017-01-03 19:00:00   1042        5.0             1.0
# 17410  2017-01-03 20:00:00    541        5.0             1.0
# 17411  2017-01-03 21:00:00    337        5.5             1.5
# 17412  2017-01-03 22:00:00    224        5.5             1.5
# 17413  2017-01-03 23:00:00    139        5.0             1.0
#
#        humidity_percent  wind_speed_kmph           weather  is_holiday  \
# 0                 0.930              6.0     Broken Clouds         0.0
# 1                 0.930              5.0             Clear         0.0
# ...

# %%
# Creating a season dictionary to map the written codes to actual values
season_dict = {'1.0' : 'Summer',
                '2.0' : 'Autumn',
                '3.0' : 'Winter',
               '0.0' : 'Spring'}

# Replacing the existing values with the required weather details
df['season'] = df['season'].astype('str')
df['season'] = df['season'].map(season_dict)
df
# Out:
#                       time  count  real_temp  temp_feel_like  \
# 0      2015-01-04 00:00:00    182        3.0             2.0
# 1      2015-01-04 01:00:00    138        3.0             2.5
# 2      2015-01-04 02:00:00    134        2.5             2.5
# 3      2015-01-04 03:00:00     72        2.0             2.0
# 4      2015-01-04 04:00:00     47        2.0             0.0
# ...                    ...    ...        ...             ...
# 17409  2017-01-03 19:00:00   1042        5.0             1.0
# 17410  2017-01-03 20:00:00    541        5.0             1.0
# 17411  2017-01-03 21:00:00    337        5.5             1.5
# 17412  2017-01-03 22:00:00    224        5.5             1.5
# 17413  2017-01-03 23:00:00    139        5.0             1.0
#
#        humidity_percent  wind_speed_kmph           weather  is_holiday  \
# 0                 0.930              6.0     Broken Clouds         0.0
# 1                 0.930              5.0             Clear         0.0
# ...

# %%
# Extracting the final dataframe to an excel
df.to_excel('london_bikes_final.xlsx', sheet_name = 'Data')
